# %%
# !pip install selenium

# %%
# !pip install webdriver_manager

# %%
import numpy as np

# %%
np.__version__
# Out:
# '1.26.4'

# %%
import pandas as pd

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By


# driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

from selenium.webdriver.chrome.service import Service


# driver = webdriver.Chrome(ChromeDriverManager().install())
service = Service()
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)

# %%
driver.get("https://tradingeconomics.com/")

# %%
html = driver.page_source
html
# Out:
# '<html><head id="ctl00_Head1"><meta charset="utf-8"><title>\n\tTRADING ECONOMICS | 20 million INDICATORS FROM 196 COUNTRIES\n</title><meta id="metaDesc" name="description" content="\n            View more than 20 million economic indicators for 196 countries. Get free indicators, Historical Data, Charts, News and Forecasts for 196 countries."><meta id="metaKeyword" name="keywords" content="Economic Indicators, Economic Data, Interest Rates, Exchange Rate Forecasts, Trading Economics, Currency Trading, Trading Signal, Trading Recommendations, Forex Signals, Trading Strategies, Forex Trading Strategies"><meta name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1,maximum-scale=1"><meta name="theme-color" content="#333333">\n<link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/bootstrap/5.2.3/css/bootstrap.min.css" integrity="sha512-SbiR/eusphKoMVVXysTKG/7VseWii+Y3FdHrt0EpKgpToZeemhqHeZeLWLhJutz/2ut2Vw1uQEj2MbRF+TVBUA==" crossorigin="anonymous" referr
# ...

# %%
from bs4 import BeautifulSoup
bs = BeautifulSoup(html)
data = bs.find("div", id="ctl00_ContentPlaceHolder1_ctl02_MarketsTableWidget_Panel1")

# %%
import io

# %%
try:
    df = pd.read_html(str(data.find("table")))
except:
    print("Hi")
# Out:
# C:\Users\sdh\AppData\Local\Temp\ipykernel_21480\3460686505.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(data.find("table")))

# %%
df2 = df[0].copy()

# %%
df2.shape
# Out:
# (15, 6)

# %%
df2 = df2.iloc[ :14 ,  :4 ]

# %%
df2.rename(columns={'Unnamed: 0' : 'Commodity'}, inplace=True)

# %%
df2
# Out:
#       Commodity   Actual    Chg    %Chg
# 0     Crude Oil   61.134   0.20  -0.32%
# 1         Brent   64.524   0.15  -0.23%
# 2   Natural gas   3.2913   0.04  -1.13%
# 3      Gasoline   2.0260   0.01  -0.30%
# 4   Heating Oil   2.0797   0.01  -0.52%
# 5          Gold  3278.53  27.53   0.85%
# 6        Silver   32.423   0.03   0.09%
# 7        Copper   4.5695   0.03  -0.68%
# 8      Soybeans  1030.99   5.01  -0.48%
# 9         Wheat   539.58   2.42  -0.45%
# 10         Coal    95.50   0.00   0.00%
# 11        Steel  3062.00   1.00   0.03%
# 12      TTF Gas    34.28   0.35  -1.01%
# 13       Lumber   573.51   4.16  -0.72%

# %%
driver.get('https://www.koreabaseball.com/')

# %%
driver.find_element(By.CSS_SELECTOR,
                    "#lnb > li:nth-child(2) > a").click()

# %%
import time 
driver.find_element(
    By.CSS_SELECTOR,
    "#lnb > li:nth-child(3)").click()
time.sleep(3)
driver.find_element(
    By.CSS_SELECTOR,
    "#cphContents_cphContents_cphContents_ddlTeam").click()
time.sleep(1)

driver.find_element(
    By.CSS_SELECTOR,
    "#cphContents_cphContents_cphContents_ddlTeam > option:nth-child(2)").click()
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# Cell In[28], line 8
#       2 driver.find_element(
#       3     By.CSS_SELECTOR,
#       4     "#lnb > li:nth-child(3)").click()
#       5 time.sleep(3)
#       6 driver.find_element(
#       7     By.CSS_SELECTOR,
# ----> 8     "#cphContents_cphContents_cphContents_ddlTeam").click()
#       9 time.sleep(1)
#      11 driver.find_element(
#      12     By.CSS_SELECTOR,
#      13     "#cphContents_cphContents_cphContents_ddlTeam > option:nth-child(2)").click()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:119, in WebElement.click(self)
#     111 def click(self) -> None:
#     112     """Clicks the element.
#     113
#     114     Example:
#    (...)
#     117     >>> element.click()
#     118     """
# --> 119     self._execute(Command.CLICK_ELEMENT)
#
# ...

# %%
kbo_bs = BeautifulSoup(driver.page_source)

# %%
pd.read_html(driver.page_source)[0]

# %%
lg = []
for x in range(1, 6):
    driver.find_element(By.CSS_SELECTOR,
    f"#cphContents_cphContents_cphContents_ucPager_btnNo{x}").click()
    time.sleep(2)
    lg.append(pd.read_html(driver.page_source)[0])

# %%
lg_df = pd.concat(lg)

# %%
lg_df.shape
# Out:
# (86, 7)

# %%
lg_df.shape
# Out:
# (86, 7)

# %%
def tmp(x):
    return int(x.split(",")[0].replace("cm", ""))

# %%
lg_df[~lg_df['체격'].apply(lambda x : len(x) > 6)]
# Out:
#     등번호  선수명  팀명  포지션        생년월일      체격     출신교
# 19  NaN  이정준  LG  NaN  1977-06-18  cm, kg  한서고-LG

# %%
lg_df = lg_df[lg_df['체격'].apply(lambda x : len(x) > 6)].copy()

# %%
lg_df['신장'] = lg_df['체격'].apply(lambda x : int(x.split(",")[0].replace("cm", "")))

# %%
lg_df['체중'] = lg_df['체격'].apply(lambda x : int(x.split(",")[1].replace("kg", "")))

# %%
lg_df['체중'] / lg_df['신장']/100**2
# Out:
# 0    0.000047
# 1    0.000050
# 2    0.000042
# 3    0.000051
# 4    0.000053
#        ...
# 1    0.000043
# 2    0.000047
# 3    0.000045
# 4    0.000047
# 5    0.000050
# Length: 85, dtype: float64
